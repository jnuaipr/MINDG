# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
threshold = [5,6,7,8,9,10]
AUPRC = [0.987,0.944,0.993,0.941,0.931,0.911]
AUROC = [0.972,0.952,0.992,0.949,0.929,0.915]
F1Score = [0.846,0.896,0.896,0.877,0.862,0.801]
Sen = [0.785,0.866,0.812,0.831,0.811,0.781]
Spec = [0.944,0.941,0.998,0.945,0.931,0.901]
ax.plot(threshold, AUPRC, label='AUPRC')
ax.plot(threshold, AUROC, label='AUROC')
ax.plot(threshold, F1Score, label='F1-Score')
ax.plot(threshold, Sen, label='Sen.')
ax.plot(threshold, Spec, label='Spec.')
ax.set_xlabel('Binding Affinity Threshold') #设置x轴名称 x label
ax.set_ylabel('Performance') #设置y轴名称 y label
ax.set_ylim(0.70,1.0)
ax.set_title("MINDG Sensitive Test based on DAVIS Dataset")
ax.legend() #自动检测要在图例中显示的元素，并且显示
plt.savefig("sensitive-davis.svg", format = "svg")
plt.show()

# %%
fig, ax = plt.subplots()
threshold = [5,6,7,8,9,10]
AUPRC = [0.813,0.981,0.988,0.971,0.972,0.901]
AUROC = [0.901,0.976,0.979,0.935,0.962,0.91]
F1Score = [0.833,0.909,0.881,0.869,0.881,0.801]
Sen = [0.714,0.801,0.916,0.909,0.916,0.851]
Spec = [0.998,0.823,0.901,0.904,0.901,0.871]
ax.plot(threshold, AUPRC, label='AUPRC')
ax.plot(threshold, AUROC, label='AUROC')
ax.plot(threshold, F1Score, label='F1-Score')
ax.plot(threshold, Sen, label='Sen.')
ax.plot(threshold, Spec, label='Spec.')
ax.set_xlabel('Binding Affinity Threshold') #设置x轴名称 x label
ax.set_ylabel('Performance') #设置y轴名称 y label
ax.set_ylim(0.70,1.0)
ax.set_title("MINDG Sensitive Test based on BindingDB Dataset")
ax.legend() #自动检测要在图例中显示的元素，并且显示

plt.savefig("sensitive-bindingdb.svg", format = "svg")
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(12,5))
threshold = [5,6,7,8,9,10]
AUPRC = [0.813,0.981,0.988,0.971,0.972,0.901]
AUROC = [0.901,0.976,0.979,0.935,0.962,0.91]
F1Score = [0.833,0.909,0.881,0.869,0.881,0.801]
Sen = [0.714,0.801,0.916,0.909,0.916,0.851]
Spec = [0.998,0.823,0.901,0.904,0.901,0.871]
ax[0].plot(threshold, AUPRC, label='AUPRC')
ax[0].plot(threshold, AUROC, label='AUROC')
ax[0].plot(threshold, F1Score, label='F1-Score')
ax[0].plot(threshold, Sen, label='Sen.')
ax[0].plot(threshold, Spec, label='Spec.')
ax[0].set_xlabel('Binding Affinity Threshold') #设置x轴名称 x label
ax[0].set_ylabel('Performance') #设置y轴名称 y label
ax[0].set_ylim(0.70,1.0)
ax[0].set_title("(a)Sensitive Test based on BindingDB Dataset")
ax[0].legend() #自动检测要在图例中显示的元素，并且显示

AUPRC = [0.987,0.944,0.993,0.941,0.931,0.911]
AUROC = [0.972,0.952,0.992,0.949,0.929,0.915]
F1Score = [0.846,0.896,0.896,0.877,0.862,0.801]
Sen = [0.785,0.866,0.812,0.831,0.811,0.781]
Spec = [0.944,0.941,0.998,0.945,0.931,0.901]
ax[1].plot(threshold, AUPRC, label='AUPRC')
ax[1].plot(threshold, AUROC, label='AUROC')
ax[1].plot(threshold, F1Score, label='F1-Score')
ax[1].plot(threshold, Sen, label='Sen.')
ax[1].plot(threshold, Spec, label='Spec.')
ax[1].set_xlabel('Binding Affinity Threshold') #设置x轴名称 x label
ax[1].set_ylabel('Performance') #设置y轴名称 y label
ax[1].set_ylim(0.70,1.0)
ax[1].set_title("(b)Sensitive Test based on DAVIS Dataset")
ax[1].legend() #自动检测要在图例中显示的元素，并且显示


plt.savefig("sensitive.svg", format = "svg")
plt.show()
